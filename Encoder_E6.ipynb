# %%
from pathlib import Path

from google.colab import drive

drive.mount("/content/drive")
root = Path("/content/drive/MyDrive/Research/PUMA")

#root = Path.cwd()
train_image_dir = root / "Dataset/01_training_dataset_tif_ROIs"
tissue_geojson_dir = root / "Dataset/01_training_dataset_geojson_tissue"
nuclei_geojson_dir = root / "Dataset/01_training_dataset_geojson_nuclei"

print("train_image_dir =", train_image_dir)
print("tissue_geojson_dir =", tissue_geojson_dir)
print("nucleu_geojson_dir =", nuclei_geojson_dir)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# train_image_dir = /content/drive/MyDrive/Research/PUMA/Dataset/01_training_dataset_tif_ROIs
# tissue_geojson_dir = /content/drive/MyDrive/Research/PUMA/Dataset/01_training_dataset_geojson_tissue
# nucleu_geojson_dir = /content/drive/MyDrive/Research/PUMA/Dataset/01_training_dataset_geojson_nuclei

# %%
from encoder import run_by_name

if __name__ == '__main__':
    # Default: train all 3 folds for this experiment.
    # To train only one fold, use: python train.py --run E1 --fold 0
    run_by_name("E6", fold=1)
# Out:
# /content/encoder/engine.py:52: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_amp):
# /content/encoder/engine.py:242: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=use_amp)
# Running E6_UNIv2_lora fold 1/2
# Train images=136 | Val images=69 | output=/content/drive/MyDrive/Research/PUMA/checkpoints_encoder/E6_UNIv2_lora/fold_1
# Epochs=20 | Batch size=4
# Trainable params=6,443,282 / Total params=687,837,458
# train:   0%|          | 0/34 [00:00<?, ?it/s]/content/encoder/engine.py:106: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_amp):
# val:   0%|          | 0/18 [00:00<?, ?it/s]/content/encoder/engine.py:153: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_amp):
# {
#   "epoch": 1,
#   "fold": 1,
#   "loss": 4.500988294096554,
#   "tissue_ce": 1.189117217765135,
#   "tissue_dice_loss": 0.6984070329105153,
#   "nuclei_fg_ce": 0.4419807747882955,
#   "nuclei_fg_dice_loss": 0.365356222671621,
#   "nuclei_class_ce": 1.3788179930518656,
#   "nuclei_class_dice_loss": 0.8546181741882773,
#   "val_loss": 3.7093007034725614,
#   "val_tissue_ce": 0.9572836955388387,
#   "val_tissue_dice_loss": 0.638337665134006,
#   "val_nuclei_fg_ce": 0.40350326399008435,
#   "val_nuclei_fg_dice_loss": 0.3316813111305237,
#   "val_nuclei_class_ce": 0.9719682335853577,
#   "val_nuclei_class_dice_loss": 0.8130531311035156,
#   "dice_tissue_background": 0.07685139902130726,
#   "dice_tissue_stroma": 0.781390248212228,
#   "dice_tissue_blood_vessel": 0.028787867527751147,
#   "dice_tissue_tumor": 0.8965440131098367,
#   "dice_tissue_epidermis": 0.6706458462267562,
#   "dice_tissue_necrosis": 0.0052130177439941505,
#   "mean_tissue_dice_scored_1_to_5": 0.4765161985641132,
#   "dice_nuclei_foreground": 0.7261651574739139,
#   "dice_nuclei_tumor": 0.9319024812646076,
#   "dice_nuclei_lymphocyte": 0.7408885964328813,
#   "dice_nuclei_plasma_cell": 0.03519718555272525,
#   "dice_nuclei_histiocyte": 0.37450488313730235,
#   "dice_nuclei_melanophage": 0.000313066617967415,
#   "dice_nuclei_neutrophil": 0.02506650901566657,
#   "dice_nuclei_stroma": 0.14079086006071695,
#   "dice_nuclei_epithelium": 0.5065127184086637,
#   "dice_nuclei_endothelium": 0.282596818254861,
#   "dice_nuclei_apoptosis": 0.00879834627941659,
#   "mean_nuclei_class_dice_on_nuclei_pixels": 0.30465714650248094,
#   "nuclei_f1": 0.7261651574739139,
#   "tissue_dice": 0.4765161985641132,
#   "nuclei_macro_f1": 0.30465714650248094,
#   "tissue_micro_dice": 0.841163399569823,
#   "official_selection_score": 0.5871254755275828,
#   "selection_score": 0.5024461675135027
# }
# Saved new best checkpoint at epoch 1 with official_selection_score=0.587125
# {
#   "epoch": 2,
#   "fold": 1,
#   "loss": 3.151153501342325,
#   "tissue_ce": 0.8129348719821257,
#   "tissue_dice_loss": 0.5827199027818792,
#   "nuclei_fg_ce": 0.31499972588875713,
#   "nuclei_fg_dice_loss": 0.26095084232442517,
#   "nuclei_class_ce": 0.7953150430146385,
#   "nuclei_class_dice_loss": 0.7684663025771871,
#   "val_loss": 2.8662046458986072,
#   "val_tissue_ce": 0.7542675915691588,
#   "val_tissue_dice_loss": 0.5665720800558726,
#   "val_nuclei_fg_ce": 0.2866020136409336,
#   "val_nuclei_fg_dice_loss": 0.24013818634880912,
#   "val_nuclei_class_ce": 0.6555525436997414,
#   "val_nuclei_class_dice_loss": 0.7261444098419614,
#   "dice_tissue_background": 0.007368596924896004,
#   "dice_tissue_stroma": 0.7911219258790484,
#   "dice_tissue_blood_vessel": 0.05474927961474191,
#   "dice_tissue_tumor": 0.897219612897559,
#   "dice_tissue_epidermis": 0.6053137811415957,
#   "dice_tissue_necrosis": 0.0010821648437801226,
#   "mean_tissue_dice_scored_1_to_5": 0.46989735287534506,
#   "dice_nuclei_foreground": 0.7651696315860067,
#   "dice_nuclei_tumor": 0.9410394138179816,
#   "dice_nuclei_lymphocyte": 0.7852258133977854,
#   "dice_nuclei_plasma_cell": 0.00015340070180821076,
#   "dice_nuclei_histiocyte": 0.5323868472876295,
#   "dice_nuclei_melanophage": 0.002289505349767472,
#   "dice_nuclei_neutrophil": 0.07059256081867761,
#   "dice_nuclei_stroma": 0.0655261331735167,
#   "dice_nuclei_epithelium": 0.6073282755076329,
#   "dice_nuclei_endothelium": 0.6058813510740382,
#   "dice_nuclei_apoptosis": 0.017563271686249715,
#   "mean_nuclei_class_dice_on_nuclei_pixels": 0.3627986572815087,
#   "nuclei_f1": 0.7651696315860067,
#   "tissue_dice": 0.46989735287534506,
#   "nuclei_macro_f1": 0.3627986572815087,
#   "tissue_micro_dice": 0.8417233286355896,
#   "official_selection_score": 0.6098972425946125,
#   "selection_score": 0.5326218805809535
# }
# Saved new best checkpoint at epoch 2 with official_selection_score=0.609897
# {
#   "epoch": 3,
#   "fold": 1,
#   "loss": 2.954861781176399,
#   "tissue_ce": 0.7659643117119285,
#   "tissue_dice_loss": 0.5858015330398784,
#   "nuclei_fg_ce": 0.282908373457544,
#   "nuclei_fg_dice_loss": 0.24014732592246113,
#   "nuclei_class_ce": 0.7150193444069695,
#   "nuclei_class_dice_loss": 0.7300418229664073,
#   "val_loss": 2.6986479229397244,
#   "val_tissue_ce": 0.7024728887610965,
#   "val_tissue_dice_loss": 0.5494316816329956,
#   "val_nuclei_fg_ce": 0.26347334931294125,
#   "val_nuclei_fg_dice_loss": 0.22936203413539463,
#   "val_nuclei_class_ce": 0.6012492982877625,
#   "val_nuclei_class_dice_loss": 0.7053172720803155,
#   "dice_tissue_background": 0.0025798018712162906,
#   "dice_tissue_stroma": 0.7982549603606498,
#   "dice_tissue_blood_vessel": 0.28146921749600873,
#   "dice_tissue_tumor": 0.898143304748469,
#   "dice_tissue_epidermis": 0.6347769981190577,
#   "dice_tissue_necrosis": 5.9151358038026605e-05,
#   "mean_tissue_dice_scored_1_to_5": 0.5225407264164447,
#   "dice_nuclei_foreground": 0.7754521667901012,
#   "dice_nuclei_tumor": 0.9434093278384321,
#   "dice_nuclei_lymphocyte": 0.7909751579305301,
#   "dice_nuclei_plasma_cell": 0.025112357871030104,
#   "dice_nuclei_histiocyte": 0.5905487199743091,
#   "dice_nuclei_melanophage": 0.03827902562480228,
#   "dice_nuclei_neutrophil": 0.10835655958143856,
#   "dice_nuclei_stroma": 0.23455332797692163,
#   "dice_nuclei_epithelium": 0.6685636782486607,
#   "dice_nuclei_endothelium": 0.6324068428115884,
#   "dice_nuclei_apoptosis": 0.1048835672021196,
#   "mean_nuclei_class_dice_on_nuclei_pixels": 0.4137088565059833,
#   "nuclei_f1": 0.7754521667901012,
#   "tissue_dice": 0.5225407264164447,
#   "nuclei_macro_f1": 0.4137088565059833,
#   "tissue_micro_dice": 0.8455091084356137,
#   "official_selection_score": 0.6393027145370357,
#   "selection_score": 0.5705672499041764
# }
# Saved new best checkpoint at epoch 3 with official_selection_score=0.639303
# {
#   "epoch": 4,
#   "fold": 1,
#   "loss": 2.6476009242674885,
#   "tissue_ce": 0.6497834806933123,
#   "tissue_dice_loss": 0.541553861954633,
#   "nuclei_fg_ce": 0.2653205394744873,
#   "nuclei_fg_dice_loss": 0.22796430657891667,
#   "nuclei_class_ce": 0.610251371474827,
#   "nuclei_class_dice_loss": 0.7054546913679909,
#   "val_loss": 2.4822626643710666,
#   "val_tissue_ce": 0.6143003188901477,
#   "val_tissue_dice_loss": 0.5219719906648,
#   "val_nuclei_fg_ce": 0.24369860771629545,
#   "val_nuclei_fg_dice_loss": 0.21185806724760267,
#   "val_nuclei_class_ce": 0.5489838148156801,
#   "val_nuclei_class_dice_loss": 0.6828997631867727,
#   "dice_tissue_background": 0.0,
#   "dice_tissue_stroma": 0.8068598637208434,
#   "dice_tissue_blood_vessel": 0.34427430137943543,
#   "dice_tissue_tumor": 0.9096271869942524,
#   "dice_tissue_epidermis": 0.6820674968388605,
#   "dice_tissue_necrosis": 0.004147372091711409,
#   "mean_tissue_dice_scored_1_to_5": 0.5493952442050205,
#   "dice_nuclei_foreground": 0.7833378612060266,
#   "dice_nuclei_tumor": 0.9463619390720392,
#   "dice_nuclei_lymphocyte": 0.8017194546852844,
#   "dice_nuclei_plasma_cell": 0.012076172782164421,
#   "dice_nuclei_histiocyte": 0.596532847279552,
#   "dice_nuclei_melanophage": 0.19497951515425882,
#   "dice_nuclei_neutrophil": 0.23929292378198483,
#   "dice_nuclei_stroma": 0.3039761610487721,
#   "dice_nuclei_epithelium": 0.7060469859943314,
#   "dice_nuclei_endothelium": 0.6411686301544011,
#   "dice_nuclei_apoptosis": 0.2145992134536131,
#   "mean_nuclei_class_dice_on_nuclei_pixels": 0.4656753843406401,
#   "nuclei_f1": 0.7833378612060266,
#   "tissue_dice": 0.5493952442050205,
#   "nuclei_macro_f1": 0.4656753843406401,
#   "tissue_micro_dice": 0.8587761353420028,
#   "official_selection_score": 0.6642961562734225,
#   "selection_score": 0.5994694965838957
# }
# Saved new best checkpoint at epoch 4 with official_selection_score=0.664296
# {
#   "epoch": 5,
#   "fold": 1,
#   "loss": 2.2997792924151703,
#   "tissue_ce": 0.47332123798482556,
#   "tissue_dice_loss": 0.48846542484620037,
#   "nuclei_fg_ce": 0.25173956331084757,
#   "nuclei_fg_dice_loss": 0.21852479086202733,
#   "nuclei_class_ce": 0.5346850410980337,
#   "nuclei_class_dice_loss": 0.6660864546018488,
#   "val_loss": 2.3666927019755044,
#   "val_tissue_ce": 0.558368504875236,
#   "val_tissue_dice_loss": 0.5108799007203844,
#   "val_nuclei_fg_ce": 0.23395157191488478,
#   "val_nuclei_fg_dice_loss": 0.20831597844759622,
#   "val_nuclei_class_ce": 0.5213843766185973,
#   "val_nuclei_class_dice_loss": 0.6675847338305579,
#   "dice_tissue_background": 0.0,
#   "dice_tissue_stroma": 0.8135423459185175,
#   "dice_tissue_blood_vessel": 0.37261290018310766,
#   "dice_tissue_tumor": 0.9045259300385565,
#   "dice_tissue_epidermis": 0.6372057304285023,
#   "dice_tissue_necrosis": 0.0028932035241694804,
#   "mean_tissue_dice_scored_1_to_5": 0.5461560220185706,
#   "dice_nuclei_foreground": 0.7882509646742327,
#   "dice_nuclei_tumor": 0.9440247160771652,
#   "dice_nuclei_lymphocyte": 0.8089899808365897,
#   "dice_nuclei_plasma_cell": 0.27547834580433606,
#   "dice_nuclei_histiocyte": 0.6052820156668777,
#   "dice_nuclei_melanophage": 0.5195892096927143,
#   "dice_nuclei_neutrophil": 0.4064789300356207,
#   "dice_nuclei_stroma": 0.3476344986100107,
#   "dice_nuclei_epithelium": 0.6720791597554158,
#   "dice_nuclei_endothelium": 0.6518180232811615,
#   "dice_nuclei_apoptosis": 0.45399637526218256,
#   "mean_nuclei_class_dice_on_nuclei_pixels": 0.5685371255022074,
#   "nuclei_f1": 0.7882509646742327,
#   "tissue_dice": 0.5461560220185706,
#   "nuclei_macro_f1": 0.5685371255022074,
#   "tissue_micro_dice": 0.8565473894847179,
#   "official_selection_score": 0.6898728754199321,
#   "selection_score": 0.6343147040650036
# }
# Saved new best checkpoint at epoch 5 with official_selection_score=0.689873
# {
#   "epoch": 6,
#   "fold": 1,
#   "loss": 2.259938583654516,
#   "tissue_ce": 0.4774133799707188,
#   "tissue_dice_loss": 0.4960546002668493,
#   "nuclei_fg_ce": 0.24420523599666707,
#   "nuclei_fg_dice_loss": 0.21110183351180134,
#   "nuclei_class_ce": 0.5059479282182806,
#   "nuclei_class_dice_loss": 0.6504312262815588,
#   "val_loss": 2.2253249684969583,
#   "val_tissue_ce": 0.5164696060948901,
#   "val_tissue_dice_loss": 0.4869159758090973,
#   "val_nuclei_fg_ce": 0.22924713873200947,
#   "val_nuclei_fg_dice_loss": 0.20429485705163744,
#   "val_nuclei_class_ce": 0.46936458183659446,
#   "val_nuclei_class_dice_loss": 0.6380655897988213,
#   "dice_tissue_background": 0.3874452157722789,
#   "dice_tissue_stroma": 0.8150110719919396,
#   "dice_tissue_blood_vessel": 0.41911521212096436,
#   "dice_tissue_tumor": 0.9057034663077963,
#   "dice_tissue_epidermis": 0.7121014361594558,
#   "dice_tissue_necrosis": 0.07173060948477018,
#   "mean_tissue_dice_scored_1_to_5": 0.5847323592129853,
#   "dice_nuclei_foreground": 0.7903044393890523,
#   "dice_nuclei_tumor": 0.9472832340821352,
#   "dice_nuclei_lymphocyte": 0.8130599483149175,
#   "dice_nuclei_plasma_cell": 0.5021995494898636,
#   "dice_nuclei_histiocyte": 0.5867479883289904,
#   "dice_nuclei_melanophage": 0.6188827632660864,
#   "dice_nuclei_neutrophil": 0.44708053248978513,
#   "dice_nuclei_stroma": 0.3943560212719091,
#   "dice_nuclei_epithelium": 0.7029934363971333,
#   "dice_nuclei_endothelium": 0.6425248859702032,
#   "dice_nuclei_apoptosis": 0.5774316613961444,
#   "mean_nuclei_class_dice_on_nuclei_pixels": 0.6232560021007169,
#   "nuclei_f1": 0.7903044393890523,
#   "tissue_dice": 0.5847323592129853,
#   "nuclei_macro_f1": 0.6232560021007169,
#   "tissue_micro_dice": 0.8610523461621445,
#   "official_selection_score": 0.7148362867162248,
#   "selection_score": 0.6660976002342515
# }
# Saved new best checkpoint at epoch 6 with official_selection_score=0.714836
# {
#   "epoch": 7,
#   "fold": 1,
#   "loss": 2.1984710623236263,
#   "tissue_ce": 0.465870696832152,
#   "tissue_dice_loss": 0.47823890693047466,
#   "nuclei_fg_ce": 0.23967781882075703,
#   "nuclei_fg_dice_loss": 0.20712903492590962,
#   "nuclei_class_ce": 0.49135585830492134,
#   "nuclei_class_dice_loss": 0.6323974833768957,
#   "val_loss": 2.201525178220537,
#   "val_tissue_ce": 0.5162437905867895,
#   "val_tissue_dice_loss": 0.4530526962545183,
#   "val_nuclei_fg_ce": 0.2204749882221222,
#   "val_nuclei_fg_dice_loss": 0.19769663943184745,
#   "val_nuclei_class_ce": 0.5048132754034467,
#   "val_nuclei_class_dice_loss": 0.6184876130686866,
#   "dice_tissue_background": 0.5166060590621636,
#   "dice_tissue_stroma": 0.8233653485334329,
#   "dice_tissue_blood_vessel": 0.4193638895497037,
#   "dice_tissue_tumor": 0.9070489500095754,
#   "dice_tissue_epidermis": 0.7323831261963625,
#   "dice_tissue_necrosis": 0.3099699097291876,
#   "mean_tissue_dice_scored_1_to_5": 0.6384262448036525,
#   "dice_nuclei_foreground": 0.7866118877183017,
#   "dice_nuclei_tumor": 0.9481915525532372,
#   "dice_nuclei_lymphocyte": 0.7821954395718904,
#   "dice_nuclei_plasma_cell": 0.5528963177016512,
#   "dice_nuclei_histiocyte": 0.5010132937057851,
#   "dice_nuclei_melanophage": 0.6004841812031572,
#   "dice_nuclei_neutrophil": 0.41113576760137177,
#   "dice_nuclei_stroma": 0.42470146419680155,
#   "dice_nuclei_epithelium": 0.6980050711158757,
#   "dice_nuclei_endothelium": 0.6613478205041652,
#   "dice_nuclei_apoptosis": 0.6122278981860405,
#   "mean_nuclei_class_dice_on_nuclei_pixels": 0.6192198806339976,
#   "nuclei_f1": 0.7866118877183017,
#   "tissue_dice": 0.6384262448036525,
#   "nuclei_macro_f1": 0.6192198806339976,
#   "tissue_micro_dice": 0.8647068429087261,
#   "official_selection_score": 0.7272412140161695,
#   "selection_score": 0.6814193377186505
# }
# Saved new best checkpoint at epoch 7 with official_selection_score=0.727241
# {
#   "epoch": 8,
#   "fold": 1,
#   "loss": 2.0474749102311978,
#   "tissue_ce": 0.39953795645166845,
#   "tissue_dice_loss": 0.4543609811979182,
#   "nuclei_fg_ce": 0.23420203915413687,
#   "nuclei_fg_dice_loss": 0.2010200163897346,
#   "nuclei_class_ce": 0.453053314019652,
#   "nuclei_class_dice_loss": 0.6106012516161975,
#   "val_loss": 2.1459099186791315,
#   "val_tissue_ce": 0.49396922770473695,
#   "val_tissue_dice_loss": 0.4606294631958008,
#   "val_nuclei_fg_ce": 0.2220808044075966,
#   "val_nuclei_fg_dice_loss": 0.19394519593980578,
#   "val_nuclei_class_ce": 0.4648238801293903,
#   "val_nuclei_class_dice_loss": 0.6209226681126488,
#   "dice_tissue_background": 0.4939585094621838,
#   "dice_tissue_stroma": 0.8188484514724855,
#   "dice_tissue_blood_vessel": 0.3448378171793581,
#   "dice_tissue_tumor": 0.9033713027638702,
#   "dice_tissue_epidermis": 0.687021561152428,
#   "dice_tissue_necrosis": 0.16730096544768142,
#   "mean_tissue_dice_scored_1_to_5": 0.5842760196031647,
#   "dice_nuclei_foreground": 0.7986105068904896,
#   "dice_nuclei_tumor": 0.9454307165943954,
#   "dice_nuclei_lymphocyte": 0.8168479506448475,
#   "dice_nuclei_plasma_cell": 0.3849429208241131,
#   "dice_nuclei_histiocyte": 0.609331283121964,
#   "dice_nuclei_melanophage": 0.5983357955346283,
#   "dice_nuclei_neutrophil": 0.37589702699624106,
#   "dice_nuclei_stroma": 0.39353673329465744,
#   "dice_nuclei_epithelium": 0.6904707545687805,
#   "dice_nuclei_endothelium": 0.597126713472706,
#   "dice_nuclei_apoptosis": 0.5783158948795633,
#   "mean_nuclei_class_dice_on_nuclei_pixels": 0.5990235789931897,
#   "nuclei_f1": 0.7986105068904896,
#   "tissue_dice": 0.5842760196031647,
#   "nuclei_macro_f1": 0.5990235789931897,
#   "tissue_micro_dice": 0.8581577510748432,
#   "official_selection_score": 0.7100169641404218,
#   "selection_score": 0.660636701828948
# }
# {
#   "epoch": 9,
#   "fold": 1,
#   "loss": 1.9377016004394083,
#   "tissue_ce": 0.35813596932327046,
#   "tissue_dice_loss": 0.4232735072865206,
#   "nuclei_fg_ce": 0.23102149367332458,
#   "nuclei_fg_dice_loss": 0.1969779256512137,
#   "nuclei_class_ce": 0.43673590745996027,
#   "nuclei_class_dice_loss": 0.5831135914606207,
#   "val_loss": 2.018857604927487,
#   "val_tissue_ce": 0.45379867032170296,
#   "val_tissue_dice_loss": 0.4346810513072544,
#   "val_nuclei_fg_ce": 0.21609335475497776,
#   "val_nuclei_fg_dice_loss": 0.19373751348919338,
#   "val_nuclei_class_ce": 0.42546603331963223,
#   "val_nuclei_class_dice_loss": 0.5901619725757175,
#   "dice_tissue_background": 0.8437696109929069,
#   "dice_tissue_stroma": 0.8096065626035182,
#   "dice_tissue_blood_vessel": 0.39791759836178575,
#   "dice_tissue_tumor": 0.9090524126422678,
#   "dice_tissue_epidermis": 0.739943351636215,
#   "dice_tissue_necrosis": 0.2971294685705155,
#   "mean_tissue_dice_scored_1_to_5": 0.6307298787628606,
#   "dice_nuclei_foreground": 0.7956412932815059,
#   "dice_nuclei_tumor": 0.9476648363740308,
#   "dice_nuclei_lymphocyte": 0.8155664898715573,
#   "dice_nuclei_plasma_cell": 0.5307876939312626,
#   "dice_nuclei_histiocyte": 0.6249433030389571,
#   "dice_nuclei_melanophage": 0.6437009439966058,
#   "dice_nuclei_neutrophil": 0.413265306122449,
#   "dice_nuclei_stroma": 0.42866772651935037,
#   "dice_nuclei_epithelium": 0.7201546881843723,
#   "dice_nuclei_endothelium": 0.6228055812734997,
#   "dice_nuclei_apoptosis": 0.598801970471303,
#   "mean_nuclei_class_dice_on_nuclei_pixels": 0.6346358539783388,
#   "nuclei_f1": 0.7956412932815059,
#   "tissue_dice": 0.6307298787628606,
#   "nuclei_macro_f1": 0.6346358539783388,
#   "tissue_micro_dice": 0.8660030963485638,
#   "official_selection_score": 0.7317525305928172,
#   "selection_score": 0.6870023420075683
# }
# Saved new best checkpoint at epoch 9 with official_selection_score=0.731753
# {
#   "epoch": 10,
#   "fold": 1,
#   "loss": 1.8364075667717878,
#   "tissue_ce": 0.3155360817909241,
#   "tissue_dice_loss": 0.4083749020800871,
#   "nuclei_fg_ce": 0.22893760835423188,
#   "nuclei_fg_dice_loss": 0.19387713600607479,
#   "nuclei_class_ce": 0.4058012138394749,
#   "nuclei_class_dice_loss": 0.5677612809573903,
#   "val_loss": 2.0573107997576394,
#   "val_tissue_ce": 0.48697856482532287,
#   "val_tissue_dice_loss": 0.43991363710827297,
#   "val_nuclei_fg_ce": 0.21492430484957165,
#   "val_nuclei_fg_dice_loss": 0.18740330470932853,
#   "val_nuclei_class_ce": 0.43549929352270234,
#   "val_nuclei_class_dice_loss": 0.5851834052138858,
#   "dice_tissue_background": 0.8452786807262348,
#   "dice_tissue_stroma": 0.8222214001812835,
#   "dice_tissue_blood_vessel": 0.40047618971932464,
#   "dice_tissue_tumor": 0.9028578255259634,
#   "dice_tissue_epidermis": 0.7000045856030607,
#   "dice_tissue_necrosis": 0.400945040437283,
#   "mean_tissue_dice_scored_1_to_5": 0.645301008293383,
#   "dice_nuclei_foreground": 0.8006193867019721,
#   "dice_nuclei_tumor": 0.9462786395392769,
#   "dice_nuclei_lymphocyte": 0.8182281410684988,
#   "dice_nuclei_plasma_cell": 0.5408454736513348,
#   "dice_nuclei_histiocyte": 0.615037514920038,
#   "dice_nuclei_melanophage": 0.5823239623731532,
#   "dice_nuclei_neutrophil": 0.3463939637672833,
#   "dice_nuclei_stroma": 0.4541599935093009,
#   "dice_nuclei_epithelium": 0.7174987729545926,
#   "dice_nuclei_endothelium": 0.6447763426846933,
#   "dice_nuclei_apoptosis": 0.5581211331077568,
#   "mean_nuclei_class_dice_on_nuclei_pixels": 0.622366393757593,
#   "nuclei_f1": 0.8006193867019721,
#   "tissue_dice": 0.645301008293383,
#   "nuclei_macro_f1": 0.622366393757593,
#   "tissue_micro_dice": 0.8618112710609166,
#   "official_selection_score": 0.7325245149534662,
#   "selection_score": 0.689428929584316
# }
# Saved new best checkpoint at epoch 10 with official_selection_score=0.732525
# {
#   "epoch": 11,
#   "fold": 1,
#   "loss": 1.7871838317197912,
#   "tissue_ce": 0.30403128353988423,
#   "tissue_dice_loss": 0.3969486496027778,
#   "nuclei_fg_ce": 0.22534284127109191,
#   "nuclei_fg_dice_loss": 0.19061276141334982,
#   "nuclei_class_ce": 0.3924416308017338,
#   "nuclei_class_dice_loss": 0.5556133231695961,
#   "val_loss": 1.99661965502633,
#   "val_tissue_ce": 0.44448473014765316,
#   "val_tissue_dice_loss": 0.4270998305744595,
#   "val_nuclei_fg_ce": 0.2176050063636568,
#   "val_nuclei_fg_dice_loss": 0.1872311664952172,
#   "val_nuclei_class_ce": 0.42961262663205463,
#   "val_nuclei_class_dice_loss": 0.5811726020442115,
#   "dice_tissue_background": 0.8585583831085868,
#   "dice_tissue_stroma": 0.8191427759663388,
#   "dice_tissue_blood_vessel": 0.38082588728466044,
#   "dice_tissue_tumor": 0.9084530401610554,
#   "dice_tissue_epidermis": 0.7600198945680373,
#   "dice_tissue_necrosis": 0.38728287752163454,
#   "mean_tissue_dice_scored_1_to_5": 0.6511448951003452,
#   "dice_nuclei_foreground": 0.8043519291899359,
#   "dice_nuclei_tumor": 0.949388399695487,
#   "dice_nuclei_lymphocyte": 0.8128157691354396,
#   "dice_nuclei_plasma_cell": 0.5426159872014122,
#   "dice_nuclei_histiocyte": 0.5760949490597712,
#   "dice_nuclei_melanophage": 0.6062709455183075,
#   "dice_nuclei_neutrophil": 0.35477318889641163,
#   "dice_nuclei_stroma": 0.45584499522949334,
#   "dice_nuclei_epithelium": 0.7275299445953425,
#   "dice_nuclei_endothelium": 0.6541267297847209,
#   "dice_nuclei_apoptosis": 0.5658820239623142,
#   "mean_nuclei_class_dice_on_nuclei_pixels": 0.62453429330787,
#   "nuclei_f1": 0.8043519291899359,
#   "tissue_dice": 0.6511448951003452,
#   "nuclei_macro_f1": 0.62453429330787,
#   "tissue_micro_dice": 0.8668594277716136,
#   "official_selection_score": 0.7367226363424412,
#   "selection_score": 0.6933437058660504
# }
# Saved new best checkpoint at epoch 11 with official_selection_score=0.736723
# {
#   "epoch": 12,
#   "fold": 1,
#   "loss": 1.703183486181147,
#   "tissue_ce": 0.28809646210249734,
#   "tissue_dice_loss": 0.35952737050897937,
#   "nuclei_fg_ce": 0.22189873632262735,
#   "nuclei_fg_dice_loss": 0.18600867250386408,
#   "nuclei_class_ce": 0.3778982175623669,
#   "nuclei_class_dice_loss": 0.539508053485085,
#   "val_loss": 1.9642616510391235,
#   "val_tissue_ce": 0.43852515187528396,
#   "val_tissue_dice_loss": 0.4098733133739895,
#   "val_nuclei_fg_ce": 0.2115490668349796,
#   "val_nuclei_fg_dice_loss": 0.18460323413213095,
#   "val_nuclei_class_ce": 0.43940841737720704,
#   "val_nuclei_class_dice_loss": 0.5606049564149644,
#   "dice_tissue_background": 0.8082586978987255,
#   "dice_tissue_stroma": 0.8145112672912018,
#   "dice_tissue_blood_vessel": 0.3913202368699751,
#   "dice_tissue_tumor": 0.9155751694445158,
#   "dice_tissue_epidermis": 0.7692116421165507,
#   "dice_tissue_necrosis": 0.557887859894585,
#   "mean_tissue_dice_scored_1_to_5": 0.6897012351233656,
#   "dice_nuclei_foreground": 0.8045248141778171,
#   "dice_nuclei_tumor": 0.946698455151764,
#   "dice_nuclei_lymphocyte": 0.8206416098150683,
#   "dice_nuclei_plasma_cell": 0.5441268620139841,
#   "dice_nuclei_histiocyte": 0.5820678088957426,
#   "dice_nuclei_melanophage": 0.6135642924731874,
#   "dice_nuclei_neutrophil": 0.42035498660856147,
#   "dice_nuclei_stroma": 0.47289404769027554,
#   "dice_nuclei_epithelium": 0.7080434707368567,
#   "dice_nuclei_endothelium": 0.6697442785884752,
#   "dice_nuclei_apoptosis": 0.5738782606333489,
#   "mean_nuclei_class_dice_on_nuclei_pixels": 0.6352014072607265,
#   "nuclei_f1": 0.8045248141778171,
#   "tissue_dice": 0.6897012351233656,
#   "nuclei_macro_f1": 0.6352014072607265,
#   "tissue_micro_dice": 0.8742397666009952,
#   "official_selection_score": 0.7509168057907261,
#   "selection_score": 0.709809152187303
# }
# Saved new best checkpoint at epoch 12 with official_selection_score=0.750917
# {
#   "epoch": 13,
#   "fold": 1,
#   "loss": 1.5847255447331596,
#   "tissue_ce": 0.23620524805258303,
#   "tissue_dice_loss": 0.3218057541286244,
#   "nuclei_fg_ce": 0.22112893356996424,
#   "nuclei_fg_dice_loss": 0.1848571125198813,
#   "nuclei_class_ce": 0.3598497772918028,
#   "nuclei_class_dice_loss": 0.5217574291369494,
#   "val_loss": 1.9121111896302965,
#   "val_tissue_ce": 0.41923313298159176,
#   "val_tissue_dice_loss": 0.40816498133871293,
#   "val_nuclei_fg_ce": 0.20727247248093286,
#   "val_nuclei_fg_dice_loss": 0.18018066551950243,
#   "val_nuclei_class_ce": 0.4150928697652287,
#   "val_nuclei_class_dice_loss": 0.5643341541290283,
#   "dice_tissue_background": 0.8970305071134594,
#   "dice_tissue_stroma": 0.8215429582283483,
#   "dice_tissue_blood_vessel": 0.38601333475742866,
#   "dice_tissue_tumor": 0.9129646160740992,
#   "dice_tissue_epidermis": 0.7622196733800252,
#   "dice_tissue_necrosis": 0.46449403076123535,
#   "mean_tissue_dice_scored_1_to_5": 0.6694469226402273,
#   "dice_nuclei_foreground": 0.802802571661637,
#   "dice_nuclei_tumor": 0.9508621053643371,
#   "dice_nuclei_lymphocyte": 0.8181971632319835,
#   "dice_nuclei_plasma_cell": 0.6201901630470195,
#   "dice_nuclei_histiocyte": 0.5595541741537565,
#   "dice_nuclei_melanophage": 0.6546796674916425,
#   "dice_nuclei_neutrophil": 0.4810909459596472,
#   "dice_nuclei_stroma": 0.4814917707036626,
#   "dice_nuclei_epithelium": 0.7204356289346897,
#   "dice_nuclei_endothelium": 0.6802023975659177,
#   "dice_nuclei_apoptosis": 0.5767156572241318,
#   "mean_nuclei_class_dice_on_nuclei_pixels": 0.6543419673676788,
#   "nuclei_f1": 0.802802571661637,
#   "tissue_dice": 0.6694469226402273,
#   "nuclei_macro_f1": 0.6543419673676788,
#   "tissue_micro_dice": 0.8721770835820074,
#   "official_selection_score": 0.7496921363128877,
#   "selection_score": 0.7088638205565144
# }
# {
#   "epoch": 14,
#   "fold": 1,
#   "loss": 1.5471057015306808,
#   "tissue_ce": 0.22234386424807942,
#   "tissue_dice_loss": 0.32569190859794617,
#   "nuclei_fg_ce": 0.21917367156814127,
#   "nuclei_fg_dice_loss": 0.18116994991021998,
#   "nuclei_class_ce": 0.3436603462871383,
#   "nuclei_class_dice_loss": 0.5101319533937118,
#   "val_loss": 1.893907778792911,
#   "val_tissue_ce": 0.4299676362425089,
#   "val_tissue_dice_loss": 0.3914590809080336,
#   "val_nuclei_fg_ce": 0.20637365927298865,
#   "val_nuclei_fg_dice_loss": 0.17790845367643568,
#   "val_nuclei_class_ce": 0.4123852273656262,
#   "val_nuclei_class_dice_loss": 0.5516274604532454,
#   "dice_tissue_background": 0.8983969453424021,
#   "dice_tissue_stroma": 0.821808155322383,
#   "dice_tissue_blood_vessel": 0.34493123665460984,
#   "dice_tissue_tumor": 0.914502704961573,
#   "dice_tissue_epidermis": 0.7668198525652582,
#   "dice_tissue_necrosis": 0.503566750757762,
#   "mean_tissue_dice_scored_1_to_5": 0.6703257400523173,
#   "dice_nuclei_foreground": 0.8043582934101073,
#   "dice_nuclei_tumor": 0.9496136850778103,
#   "dice_nuclei_lymphocyte": 0.8234039399272274,
#   "dice_nuclei_plasma_cell": 0.41392656115754906,
#   "dice_nuclei_histiocyte": 0.6079699378781531,
#   "dice_nuclei_melanophage": 0.6591595100075861,
#   "dice_nuclei_neutrophil": 0.4516548634195693,
#   "dice_nuclei_stroma": 0.472841332912157,
#   "dice_nuclei_epithelium": 0.718849098716153,
#   "dice_nuclei_endothelium": 0.6073234783738389,
#   "dice_nuclei_apoptosis": 0.6054260363715814,
#   "mean_nuclei_class_dice_on_nuclei_pixels": 0.6310168443841626,
#   "nuclei_f1": 0.8043582934101073,
#   "tissue_dice": 0.6703257400523173,
#   "nuclei_macro_f1": 0.6310168443841626,
#   "tissue_micro_dice": 0.8732545284197701,
#   "official_selection_score": 0.7447388515665894,
#   "selection_score": 0.701900292615529
# }
# {
#   "epoch": 15,
#   "fold": 1,
#   "loss": 1.5844146433998556,
#   "tissue_ce": 0.23859717696905136,
#   "tissue_dice_loss": 0.3420874827048358,
#   "nuclei_fg_ce": 0.2190168872475624,
#   "nuclei_fg_dice_loss": 0.1810001064749325,
#   "nuclei_class_ce": 0.3467344895881765,
#   "nuclei_class_dice_loss": 0.5139570043367498,
#   "val_loss": 1.9365187817149692,
#   "val_tissue_ce": 0.46432728982634014,
#   "val_tissue_dice_loss": 0.3997712996270921,
#   "val_nuclei_fg_ce": 0.20840707504087025,
#   "val_nuclei_fg_dice_loss": 0.17688710821999443,
#   "val_nuclei_class_ce": 0.4159636828634474,
#   "val_nuclei_class_dice_loss": 0.5423245860470666,
#   "dice_tissue_background": 0.8889406185073587,
#   "dice_tissue_stroma": 0.8103765309494231,
#   "dice_tissue_blood_vessel": 0.4050315240675727,
#   "dice_tissue_tumor": 0.9082764224553131,
#   "dice_tissue_epidermis": 0.7547017908573798,
#   "dice_tissue_necrosis": 0.5353593783232019,
#   "mean_tissue_dice_scored_1_to_5": 0.6827491293305782,
#   "dice_nuclei_foreground": 0.8084551483261407,
#   "dice_nuclei_tumor": 0.9482996434847676,
#   "dice_nuclei_lymphocyte": 0.8180049484012403,
#   "dice_nuclei_plasma_cell": 0.5791911201837203,
#   "dice_nuclei_histiocyte": 0.5606287788321804,
#   "dice_nuclei_melanophage": 0.6334898557340363,
#   "dice_nuclei_neutrophil": 0.5140042385016323,
#   "dice_nuclei_stroma": 0.4754028812172808,
#   "dice_nuclei_epithelium": 0.7215103770789586,
#   "dice_nuclei_endothelium": 0.6761955461146121,
#   "dice_nuclei_apoptosis": 0.6066151499094959,
#   "mean_nuclei_class_dice_on_nuclei_pixels": 0.6533342539457925,
#   "nuclei_f1": 0.8084551483261407,
#   "tissue_dice": 0.6827491293305782,
#   "nuclei_macro_f1": 0.6533342539457925,
#   "tissue_micro_dice": 0.8664637329763692,
#   "official_selection_score": 0.7527505661447201,
#   "selection_score": 0.7148461772008371
# }
# Saved new best checkpoint at epoch 15 with official_selection_score=0.752751
# {
#   "epoch": 16,
#   "fold": 1,
#   "loss": 1.5346962774501127,
#   "tissue_ce": 0.21586654401000807,
#   "tissue_dice_loss": 0.33701800423509937,
#   "nuclei_fg_ce": 0.218075313112315,
#   "nuclei_fg_dice_loss": 0.17908991084379308,
#   "nuclei_class_ce": 0.3364681005477905,
#   "nuclei_class_dice_loss": 0.4963568308774163,
#   "val_loss": 1.917719132370419,
#   "val_tissue_ce": 0.44284822460677886,
#   "val_tissue_dice_loss": 0.4006376895639632,
#   "val_nuclei_fg_ce": 0.2047348991036415,
#   "val_nuclei_fg_dice_loss": 0.1743796600235833,
#   "val_nuclei_class_ce": 0.42360472058256465,
#   "val_nuclei_class_dice_loss": 0.5430278480052948,
#   "dice_tissue_background": 0.8982950204019441,
#   "dice_tissue_stroma": 0.8154634106492027,
#   "dice_tissue_blood_vessel": 0.37904613920995683,
#   "dice_tissue_tumor": 0.9134047345117161,
#   "dice_tissue_epidermis": 0.7747511788060604,
#   "dice_tissue_necrosis": 0.4315494119774332,
#   "mean_tissue_dice_scored_1_to_5": 0.6628429750308739,
#   "dice_nuclei_foreground": 0.8092281760335427,
#   "dice_nuclei_tumor": 0.9501687892930192,
#   "dice_nuclei_lymphocyte": 0.8175516841497529,
#   "dice_nuclei_plasma_cell": 0.6120223788556755,
#   "dice_nuclei_histiocyte": 0.5660155764728367,
#   "dice_nuclei_melanophage": 0.6211925588801739,
#   "dice_nuclei_neutrophil": 0.3983560839571408,
#   "dice_nuclei_stroma": 0.45049000645547277,
#   "dice_nuclei_epithelium": 0.7118537987979349,
#   "dice_nuclei_endothelium": 0.6703965931754053,
#   "dice_nuclei_apoptosis": 0.5515288293535235,
#   "mean_nuclei_class_dice_on_nuclei_pixels": 0.6349576299390935,
#   "nuclei_f1": 0.8092281760335427,
#   "tissue_dice": 0.6628429750308739,
#   "nuclei_macro_f1": 0.6349576299390935,
#   "tissue_micro_dice": 0.871183039056066,
#   "official_selection_score": 0.7445529550148942,
#   "selection_score": 0.7023429270011702
# }
# {
#   "epoch": 17,
#   "fold": 1,
#   "loss": 1.422791400376488,
#   "tissue_ce": 0.18702986902173827,
#   "tissue_dice_loss": 0.28740955626263337,
#   "nuclei_fg_ce": 0.216825429131003,
#   "nuclei_fg_dice_loss": 0.1774202164481668,
#   "nuclei_class_ce": 0.3151918899487047,
#   "nuclei_class_dice_loss": 0.47782886904828686,
#   "val_loss": 1.9610063566101923,
#   "val_tissue_ce": 0.46043596665064496,
#   "val_tissue_dice_loss": 0.4024426009919908,
#   "val_nuclei_fg_ce": 0.2050256704290708,
#   "val_nuclei_fg_dice_loss": 0.17258844441837734,
#   "val_nuclei_class_ce": 0.4477253630757332,
#   "val_nuclei_class_dice_loss": 0.5455765724182129,
#   "dice_tissue_background": 0.8679265839758632,
#   "dice_tissue_stroma": 0.8179107728803116,
#   "dice_tissue_blood_vessel": 0.32848017173515753,
#   "dice_tissue_tumor": 0.9076124140195074,
#   "dice_tissue_epidermis": 0.7426180097746077,
#   "dice_tissue_necrosis": 0.3351888467814459,
#   "mean_tissue_dice_scored_1_to_5": 0.626362043038206,
#   "dice_nuclei_foreground": 0.8120106515720815,
#   "dice_nuclei_tumor": 0.9502138586605079,
#   "dice_nuclei_lymphocyte": 0.8240120436582612,
#   "dice_nuclei_plasma_cell": 0.5883529907329402,
#   "dice_nuclei_histiocyte": 0.609544773073211,
#   "dice_nuclei_melanophage": 0.6335863932731048,
#   "dice_nuclei_neutrophil": 0.39397270312356875,
#   "dice_nuclei_stroma": 0.4479762498572708,
#   "dice_nuclei_epithelium": 0.6885455848110335,
#   "dice_nuclei_endothelium": 0.6211070044974841,
#   "dice_nuclei_apoptosis": 0.5251804031601919,
#   "mean_nuclei_class_dice_on_nuclei_pixels": 0.6282492004847575,
#   "nuclei_f1": 0.8120106515720815,
#   "tissue_dice": 0.626362043038206,
#   "nuclei_macro_f1": 0.6282492004847575,
#   "tissue_micro_dice": 0.8644995783290649,
#   "official_selection_score": 0.7327803683560274,
#   "selection_score": 0.6888739650316816
# }
# {
#   "epoch": 18,
#   "fold": 1,
#   "loss": 1.4721955201205086,
#   "tissue_ce": 0.19836419492083437,
#   "tissue_dice_loss": 0.32102221425841837,
#   "nuclei_fg_ce": 0.21704171072034276,
#   "nuclei_fg_dice_loss": 0.17646101292441874,
#   "nuclei_class_ce": 0.3212410592857529,
#   "nuclei_class_dice_loss": 0.4761306608424467,
#   "val_loss": 1.9855405886967976,
#   "val_tissue_ce": 0.4857688239879078,
#   "val_tissue_dice_loss": 0.41745620634820724,
#   "val_nuclei_fg_ce": 0.20642220146126217,
#   "val_nuclei_fg_dice_loss": 0.17089059948921204,
#   "val_nuclei_class_ce": 0.43463356006476617,
#   "val_nuclei_class_dice_loss": 0.5407383806175656,
#   "dice_tissue_background": 0.8902344065242095,
#   "dice_tissue_stroma": 0.8115945149166478,
#   "dice_tissue_blood_vessel": 0.20139681776602636,
#   "dice_tissue_tumor": 0.9018835993391613,
#   "dice_tissue_epidermis": 0.7603942334638591,
#   "dice_tissue_necrosis": 0.45220311663970686,
#   "mean_tissue_dice_scored_1_to_5": 0.6254944564250803,
#   "dice_nuclei_foreground": 0.8073092607876412,
#   "dice_nuclei_tumor": 0.9444484157753119,
#   "dice_nuclei_lymphocyte": 0.8169911638269529,
#   "dice_nuclei_plasma_cell": 0.5982790597913171,
#   "dice_nuclei_histiocyte": 0.5510315658487831,
#   "dice_nuclei_melanophage": 0.5506862978944858,
#   "dice_nuclei_neutrophil": 0.40591947769314474,
#   "dice_nuclei_stroma": 0.4695309034958194,
#   "dice_nuclei_epithelium": 0.7114169793419755,
#   "dice_nuclei_endothelium": 0.6333672597470392,
#   "dice_nuclei_apoptosis": 0.5705542122327856,
#   "mean_nuclei_class_dice_on_nuclei_pixels": 0.6252225335647615,
#   "nuclei_f1": 0.8073092607876412,
#   "tissue_dice": 0.6254944564250803,
#   "nuclei_macro_f1": 0.6252225335647615,
#   "tissue_micro_dice": 0.8598625986447462,
#   "official_selection_score": 0.7294722123555574,
#   "selection_score": 0.6860087502591611
# }
# {
#   "epoch": 19,
#   "fold": 1,
#   "loss": 1.3666611594312332,
#   "tissue_ce": 0.17635785371941679,
#   "tissue_dice_loss": 0.2761210413540111,
#   "nuclei_fg_ce": 0.213362319066244,
#   "nuclei_fg_dice_loss": 0.1733905041919035,
#   "nuclei_class_ce": 0.3001895213828367,
#   "nuclei_class_dice_loss": 0.4544798451311448,
#   "val_loss": 1.8681642843617334,
#   "val_tissue_ce": 0.43681148232685196,
#   "val_tissue_dice_loss": 0.3833363718456692,
#   "val_nuclei_fg_ce": 0.20485713415675694,
#   "val_nuclei_fg_dice_loss": 0.17104565766122606,
#   "val_nuclei_class_ce": 0.40712695941329,
#   "val_nuclei_class_dice_loss": 0.5299732983112335,
#   "dice_tissue_background": 0.8894928393559364,
#   "dice_tissue_stroma": 0.8177463499479238,
#   "dice_tissue_blood_vessel": 0.4112491413343044,
#   "dice_tissue_tumor": 0.9073065699186139,
#   "dice_tissue_epidermis": 0.7849297938429627,
#   "dice_tissue_necrosis": 0.4096703456430196,
#   "mean_tissue_dice_scored_1_to_5": 0.666180440137365,
#   "dice_nuclei_foreground": 0.8115101104323313,
#   "dice_nuclei_tumor": 0.9480988759307254,
#   "dice_nuclei_lymphocyte": 0.8228962405357624,
#   "dice_nuclei_plasma_cell": 0.608634529330915,
#   "dice_nuclei_histiocyte": 0.6225096431416677,
#   "dice_nuclei_melanophage": 0.6387696532614209,
#   "dice_nuclei_neutrophil": 0.43642182109105454,
#   "dice_nuclei_stroma": 0.4289504825325425,
#   "dice_nuclei_epithelium": 0.731013607664562,
#   "dice_nuclei_endothelium": 0.6873507986828067,
#   "dice_nuclei_apoptosis": 0.5571676074033105,
#   "mean_nuclei_class_dice_on_nuclei_pixels": 0.6481813259574768,
#   "nuclei_f1": 0.8115101104323313,
#   "tissue_dice": 0.666180440137365,
#   "nuclei_macro_f1": 0.6481813259574768,
#   "tissue_micro_dice": 0.8662216873629117,
#   "official_selection_score": 0.7480233909725212,
#   "selection_score": 0.708623958842391
# }
# {
#   "epoch": 20,
#   "fold": 1,
#   "loss": 1.3571130703477299,
#   "tissue_ce": 0.17016814583364656,
#   "tissue_dice_loss": 0.2858522604493534,
#   "nuclei_fg_ce": 0.2127058321938795,
#   "nuclei_fg_dice_loss": 0.17227757503004634,
#   "nuclei_class_ce": 0.29303167891852994,
#   "nuclei_class_dice_loss": 0.44615516767782326,
#   "val_loss": 1.941880053944058,
#   "val_tissue_ce": 0.47117685133384335,
#   "val_tissue_dice_loss": 0.41872310638427734,
#   "val_nuclei_fg_ce": 0.20047859185271794,
#   "val_nuclei_fg_dice_loss": 0.17082488536834717,
#   "val_nuclei_class_ce": 0.4143473398354318,
#   "val_nuclei_class_dice_loss": 0.532658576965332,
#   "dice_tissue_background": 0.8889957791146728,
#   "dice_tissue_stroma": 0.8120586403785043,
#   "dice_tissue_blood_vessel": 0.20674728788882718,
#   "dice_tissue_tumor": 0.9026975177222001,
#   "dice_tissue_epidermis": 0.7813412821003969,
#   "dice_tissue_necrosis": 0.2795524063570535,
#   "mean_tissue_dice_scored_1_to_5": 0.5964794268893965,
#   "dice_nuclei_foreground": 0.8047837827188535,
#   "dice_nuclei_tumor": 0.9462198069463368,
#   "dice_nuclei_lymphocyte": 0.8216769377775672,
#   "dice_nuclei_plasma_cell": 0.5741066035312333,
#   "dice_nuclei_histiocyte": 0.6072094301199237,
#   "dice_nuclei_melanophage": 0.6071742059415979,
#   "dice_nuclei_neutrophil": 0.4278582126809785,
#   "dice_nuclei_stroma": 0.4614198694770653,
#   "dice_nuclei_epithelium": 0.7348525379729084,
#   "dice_nuclei_endothelium": 0.6674048519626139,
#   "dice_nuclei_apoptosis": 0.5469453796504665,
#   "mean_nuclei_class_dice_on_nuclei_pixels": 0.6394867836060691,
#   "nuclei_f1": 0.8047837827188535,
#   "tissue_dice": 0.5964794268893965,
#   "nuclei_macro_f1": 0.6394867836060691,
#   "tissue_micro_dice": 0.8602744559464626,
#   "official_selection_score": 0.7252561122901955,
#   "selection_score": 0.6802499977381063
# }

# %%
from __future__ import annotations

from pathlib import Path

import numpy as np
import pandas as pd

from encoder.config import ENCODER_RUNS, OUTPUT_DIR


def summarize() -> Path:
    rows = []
    for key, cfg in ENCODER_RUNS.items():
        for fold_id in range(cfg.n_folds):
            metrics_path = OUTPUT_DIR / cfg.experiment_name / f'fold_{fold_id}' / 'metrics.csv'
            if not metrics_path.exists():
                rows.append({
                    'run': key,
                    'experiment': cfg.experiment_name,
                    'fold': fold_id,
                    'status': 'missing',
                })
                continue
            df = pd.read_csv(metrics_path)
            if df.empty or 'selection_score' not in df.columns:
                rows.append({
                    'run': key,
                    'experiment': cfg.experiment_name,
                    'fold': fold_id,
                    'status': 'empty_or_incomplete',
                })
                continue
            best_idx = df['selection_score'].idxmax()
            best = df.loc[best_idx].to_dict()
            rows.append({
                'run': key,
                'experiment': cfg.experiment_name,
                'fold': fold_id,
                'status': 'ok',
                'best_epoch': int(best.get('epoch', -1)),
                'selection_score': float(best.get('selection_score', np.nan)),
                'mean_tissue_dice_scored_1_to_5': float(best.get('mean_tissue_dice_scored_1_to_5', np.nan)),
                'dice_nuclei_foreground': float(best.get('dice_nuclei_foreground', np.nan)),
                'mean_nuclei_class_dice_on_nuclei_pixels': float(best.get('mean_nuclei_class_dice_on_nuclei_pixels', np.nan)),
            })

    summary = pd.DataFrame(rows)
    OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
    out_path = OUTPUT_DIR / 'comparison_summary_by_fold.csv'
    summary.to_csv(out_path, index=False)

    ok = summary[summary['status'] == 'ok'].copy()
    if not ok.empty:
        agg = ok.groupby(['run', 'experiment'], as_index=False).agg(
            folds_done=('fold', 'count'),
            selection_score_mean=('selection_score', 'mean'),
            selection_score_std=('selection_score', 'std'),
            tissue_dice_mean=('mean_tissue_dice_scored_1_to_5', 'mean'),
            nuclei_fg_dice_mean=('dice_nuclei_foreground', 'mean'),
            nuclei_class_dice_mean=('mean_nuclei_class_dice_on_nuclei_pixels', 'mean'),
        ).sort_values('selection_score_mean', ascending=False)
        agg_path = OUTPUT_DIR / 'comparison_summary_mean_over_folds.csv'
        agg.to_csv(agg_path, index=False)
        print(agg.to_string(index=False))
        print(f'Wrote {agg_path}')
    print(f'Wrote {out_path}')
    return out_path


if __name__ == '__main__':
    summarize()
# Out:
# run                              experiment  folds_done  selection_score_mean  selection_score_std  tissue_dice_mean  nuclei_fg_dice_mean  nuclei_class_dice_mean
#  E6                           E6_UNIv2_lora           1              0.714846                  NaN          0.682749             0.808455                0.653334
#  E1                         E1_UNIv2_frozen           3              0.668853             0.021864          0.604930             0.791113                0.610515
#  E3                      E3_Virchow2_frozen           3              0.663088             0.019291          0.621337             0.782157                0.585771
#  E4    E4_ConvNeXtV2_atto_plus_UNIv2_frozen           3              0.563104             0.038244          0.606932             0.558808                0.523571
#  E5 E5_ConvNeXtV2_atto_plus_Virchow2_frozen           3              0.545639             0.005933          0.599346             0.564919                0.472651
#  E2               E2_ConvNeXtV2_atto_frozen           3              0.351761             0.021770          0.370793             0.462648                0.221842
# Wrote /content/drive/MyDrive/Research/PUMA/checkpoints_encoder/comparison_summary_mean_over_folds.csv
# Wrote /content/drive/MyDrive/Research/PUMA/checkpoints_encoder/comparison_summary_by_fold.csv

# %%
"""
Simple E6 inference script with colored visualization masks.

Purpose:
- Load one trained E6 checkpoint.
- Load one image path.
- Run model inference only.
- Save raw prediction masks for evaluation/submission.
- Save colored PNG masks for visual checking.

No fold logic. No validation split. No ground-truth loading.

Put this file in the project folder, next to the `encoder/` directory.
Then edit only the USER SETTINGS section below.
"""

from __future__ import annotations

from dataclasses import replace
from pathlib import Path

import numpy as np
import torch
from PIL import Image

try:
    import tifffile
except Exception:
    tifffile = None

from encoder.config import ENCODER_RUNS
from encoder.data import IMAGENET_MEAN, IMAGENET_STD
from encoder.engine import _initialize_lazy_modules
from encoder.models import PumaEncoderProbe


# ==========================================================
# USER SETTINGS: edit these paths only
# ==========================================================

# Your trained E6 checkpoint.
checkpoint_path = Path(
    "/content/drive/MyDrive/Research/PUMA/checkpoints_encoder/E6_UNIv2_lora/fold_1/best_model.pth"
)

# The image you want to run inference on.
image_path = Path(
    "/content/drive/MyDrive/Research/PUMA/Dataset/01_training_dataset_tif_ROIs/training_set_metastatic_roi_001.tif"
)

# Where to save outputs.
output_dir = Path(
    "/content/drive/MyDrive/Research/PUMA/e6_inference_outputs"
)

# E6 was trained with 1024x1024 ROI input in your current code.
image_size = 1024

# Save raw ID masks. Keep this True for useful inference output.
save_raw_masks = True

# Save colored PNG masks for visual inspection.
save_colored_previews = True

# Save a side-by-side overview PNG: original image + tissue + nuclei foreground + nuclei class.
save_overview_png = True


# ==========================================================
# Label meaning for your current E6 code
# ==========================================================

# Tissue prediction is already in official PUMA Track 2 IDs:
# 0 = background
# 1 = stroma
# 2 = blood vessel
# 3 = tumor
# 4 = epidermis / epithelium
# 5 = necrosis
# Therefore, no tissue remapping is needed here.

TISSUE_ID_TO_NAME = {
    0: "background",
    1: "stroma",
    2: "blood_vessel",
    3: "tumor",
    4: "epidermis",
    5: "necrosis",
}

NUCLEI_ID_TO_NAME = {
    0: "tumor",
    1: "lymphocyte",
    2: "plasma_cell",
    3: "histiocyte",
    4: "melanophage",
    5: "neutrophil",
    6: "stroma",
    7: "epithelium",
    8: "endothelium",
    9: "apoptosis",
}

# RGB colors for official PUMA tissue IDs.
TISSUE_COLORS = {
    0: (0, 0, 0),          # background - black
    1: (0, 180, 0),        # stroma - green
    2: (0, 180, 255),      # blood vessel - cyan
    3: (255, 0, 0),        # tumor - red
    4: (255, 200, 0),      # epidermis / epithelium - yellow/orange
    5: (120, 0, 180),      # necrosis - purple
}

# RGB colors for nuclei class IDs.
# 255 is used only for visualization/background after masking with nuclei foreground.
NUCLEI_COLORS_WITH_BG = {
    255: (0, 0, 0),        # background - black
    0: (255, 0, 0),        # tumor - red
    1: (0, 0, 255),        # lymphocyte - blue
    2: (255, 0, 255),      # plasma cell - magenta
    3: (255, 140, 0),      # histiocyte - orange
    4: (120, 70, 20),      # melanophage - brown
    5: (0, 255, 255),      # neutrophil - cyan
    6: (0, 180, 0),        # stromal - green
    7: (255, 220, 0),      # epithelium - yellow
    8: (0, 150, 150),      # endothelium - teal
    9: (180, 180, 180),    # apoptosis - gray
}

NUCLEI_FG_COLORS = {
    0: (0, 0, 0),          # background - black
    1: (255, 255, 255),    # nuclei foreground - white
}


def read_rgb_image(path: Path) -> np.ndarray:
    """Read tif/png/jpg image as uint8 RGB numpy array [H, W, 3]."""
    if not path.exists():
        raise FileNotFoundError(f"Image not found: {path}")

    if path.suffix.lower() in {".tif", ".tiff"} and tifffile is not None:
        img = tifffile.imread(str(path))
    else:
        img = np.array(Image.open(path))

    # Handle channel layout and grayscale/RGBA cases.
    if img.ndim == 2:
        img = np.stack([img, img, img], axis=-1)
    elif img.ndim == 3 and img.shape[0] in {3, 4} and img.shape[-1] not in {3, 4}:
        # Convert [C, H, W] to [H, W, C] if needed.
        img = np.transpose(img, (1, 2, 0))
    elif img.ndim > 3:
        # If a TIFF has extra dimensions, use the first plane.
        img = np.squeeze(img)
        if img.ndim == 2:
            img = np.stack([img, img, img], axis=-1)
        if img.ndim == 3 and img.shape[0] in {3, 4} and img.shape[-1] not in {3, 4}:
            img = np.transpose(img, (1, 2, 0))

    if img.ndim != 3:
        raise ValueError(f"Unsupported image shape after loading: {img.shape}")

    if img.shape[-1] == 4:
        img = img[..., :3]
    if img.shape[-1] != 3:
        raise ValueError(f"Expected RGB image with 3 channels, got shape: {img.shape}")

    # Convert to uint8 if needed.
    if img.dtype != np.uint8:
        img = img.astype(np.float32)
        max_value = float(np.nanmax(img)) if img.size else 0.0
        if max_value <= 1.0:
            img = img * 255.0
        elif max_value > 255.0:
            img = img / max_value * 255.0
        img = np.clip(img, 0, 255).astype(np.uint8)

    return img


def resize_if_needed(img: np.ndarray, size: int) -> np.ndarray:
    """Resize image to model input size if needed."""
    h, w = img.shape[:2]
    if h == size and w == size:
        return img

    print(f"Input image is {h}x{w}. Resizing to {size}x{size} for E6 model.")
    pil_img = Image.fromarray(img)
    pil_img = pil_img.resize((size, size), resample=Image.BILINEAR)
    return np.array(pil_img, dtype=np.uint8)


def preprocess_image(img: np.ndarray) -> torch.Tensor:
    """Convert uint8 RGB [H, W, 3] to normalized tensor [1, 3, H, W]."""
    x = torch.from_numpy(np.ascontiguousarray(img)).float().permute(2, 0, 1) / 255.0
    x = (x - IMAGENET_MEAN) / IMAGENET_STD
    return x.unsqueeze(0)


def save_mask(path: Path, mask: np.ndarray) -> None:
    """Save mask as tif if tifffile exists, otherwise save as png."""
    path.parent.mkdir(parents=True, exist_ok=True)
    if path.suffix.lower() in {".tif", ".tiff"} and tifffile is not None:
        tifffile.imwrite(str(path), mask.astype(np.uint8))
    else:
        Image.fromarray(mask.astype(np.uint8)).save(path)


def colorize_mask(mask: np.ndarray, color_dict: dict[int, tuple[int, int, int]]) -> np.ndarray:
    """
    Convert a 2D label mask into an RGB image.

    Unknown labels are colored black by default.
    """
    mask = np.asarray(mask)
    if mask.ndim != 2:
        raise ValueError(f"Expected a 2D mask, got shape: {mask.shape}")

    h, w = mask.shape
    rgb = np.zeros((h, w, 3), dtype=np.uint8)

    for class_id, color in color_dict.items():
        rgb[mask == class_id] = color

    return rgb


def save_color_mask(mask: np.ndarray, color_dict: dict[int, tuple[int, int, int]], save_path: Path) -> None:
    """Save a colored RGB PNG from a 2D label mask."""
    save_path.parent.mkdir(parents=True, exist_ok=True)
    rgb = colorize_mask(mask, color_dict)
    Image.fromarray(rgb).save(save_path)


def save_overlay(
    image_rgb: np.ndarray,
    color_mask_rgb: np.ndarray,
    save_path: Path,
    alpha: float = 0.45,
) -> None:
    """Save a simple overlay of color mask on top of original RGB image."""
    if image_rgb.shape[:2] != color_mask_rgb.shape[:2]:
        raise ValueError(
            f"Image and mask sizes do not match: {image_rgb.shape} vs {color_mask_rgb.shape}"
        )

    image_f = image_rgb.astype(np.float32)
    mask_f = color_mask_rgb.astype(np.float32)
    overlay = (1.0 - alpha) * image_f + alpha * mask_f
    overlay = np.clip(overlay, 0, 255).astype(np.uint8)

    save_path.parent.mkdir(parents=True, exist_ok=True)
    Image.fromarray(overlay).save(save_path)


def make_overview_png(
    image_rgb: np.ndarray,
    tissue_rgb: np.ndarray,
    nuclei_fg_rgb: np.ndarray,
    nuclei_class_rgb: np.ndarray,
    save_path: Path,
) -> None:
    """Save one side-by-side PNG for quick visual checking."""
    h, w = image_rgb.shape[:2]
    panels = [image_rgb, tissue_rgb, nuclei_fg_rgb, nuclei_class_rgb]
    canvas = np.zeros((h, w * len(panels), 3), dtype=np.uint8)

    for i, panel in enumerate(panels):
        canvas[:, i * w : (i + 1) * w] = panel

    save_path.parent.mkdir(parents=True, exist_ok=True)
    Image.fromarray(canvas).save(save_path)


def print_class_counts(name: str, mask: np.ndarray, id_to_name: dict[int, str], ignore_id: int | None = None) -> None:
    """Print pixel counts for a predicted mask."""
    print(f"\n{name} pixel counts:")
    unique_ids, counts = np.unique(mask, return_counts=True)
    for class_id, count in zip(unique_ids.tolist(), counts.tolist()):
        if ignore_id is not None and class_id == ignore_id:
            class_name = "background_or_non_nuclei"
        else:
            class_name = id_to_name.get(int(class_id), "unknown")
        print(f"  {class_id}: {class_name}: {count}")


def load_e6_model(checkpoint_path: Path, device: torch.device) -> PumaEncoderProbe:
    """Build E6 model, initialize lazy layers, and load checkpoint weights."""
    if not checkpoint_path.exists():
        raise FileNotFoundError(f"Checkpoint not found: {checkpoint_path}")

    # E6 config: UNIv2 LoRA. Use pretrained=False because the checkpoint already
    # contains the trained weights. This avoids unnecessary pretrained download.
    cfg = replace(ENCODER_RUNS["E6"], pretrained=False, image_size=image_size)

    model = PumaEncoderProbe(cfg).to(device)

    use_amp = bool(cfg.amp and device.type == "cuda")
    _initialize_lazy_modules(model=model, cfg=cfg, device=device, use_amp=use_amp)

    checkpoint = torch.load(checkpoint_path, map_location=device)

    if isinstance(checkpoint, dict) and "model_state" in checkpoint:
        state_dict = checkpoint["model_state"]
    elif isinstance(checkpoint, dict) and "model" in checkpoint:
        state_dict = checkpoint["model"]
    else:
        state_dict = checkpoint

    model.load_state_dict(state_dict, strict=True)
    model.eval()

    print(f"Loaded checkpoint: {checkpoint_path}")
    if isinstance(checkpoint, dict) and "epoch" in checkpoint:
        print(f"Checkpoint epoch: {checkpoint['epoch']}")

    return model


def run_inference() -> None:
    output_dir.mkdir(parents=True, exist_ok=True)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Using device: {device}")

    model = load_e6_model(checkpoint_path, device)

    img = read_rgb_image(image_path)
    original_h, original_w = img.shape[:2]
    img_for_model = resize_if_needed(img, image_size)
    x = preprocess_image(img_for_model).to(device)

    use_amp = device.type == "cuda"
    with torch.no_grad():
        with torch.cuda.amp.autocast(enabled=use_amp):
            outputs = model(x)

    tissue_pred = outputs["tissue"].argmax(dim=1)[0].cpu().numpy().astype(np.uint8)
    nuclei_fg_pred = outputs["nuclei_fg"].argmax(dim=1)[0].cpu().numpy().astype(np.uint8)
    nuclei_class_pred = outputs["nuclei_class"].argmax(dim=1)[0].cpu().numpy().astype(np.uint8)

    # Keep nuclei class only where the model predicts nuclei foreground.
    # Background pixels are set to 255 because nuclei_class has no real background class.
    nuclei_class_masked = np.where(nuclei_fg_pred > 0, nuclei_class_pred, 255).astype(np.uint8)

    # If the original image was not 1024x1024, resize predictions back to original size.
    if (original_h, original_w) != (image_size, image_size):
        tissue_pred = np.array(
            Image.fromarray(tissue_pred).resize((original_w, original_h), resample=Image.NEAREST),
            dtype=np.uint8,
        )
        nuclei_fg_pred = np.array(
            Image.fromarray(nuclei_fg_pred).resize((original_w, original_h), resample=Image.NEAREST),
            dtype=np.uint8,
        )
        nuclei_class_masked = np.array(
            Image.fromarray(nuclei_class_masked).resize((original_w, original_h), resample=Image.NEAREST),
            dtype=np.uint8,
        )

    stem = image_path.stem

    if save_raw_masks:
        # Save numpy arrays.
        np.save(output_dir / f"{stem}_tissue_puma_ids.npy", tissue_pred)
        np.save(output_dir / f"{stem}_nuclei_fg.npy", nuclei_fg_pred)
        np.save(output_dir / f"{stem}_nuclei_class_masked.npy", nuclei_class_masked)

        # Save raw ID masks. These are the important files for evaluation/submission-style use.
        save_mask(output_dir / f"{stem}_tissue_puma_ids.tif", tissue_pred)
        save_mask(output_dir / f"{stem}_nuclei_fg.tif", nuclei_fg_pred)
        save_mask(output_dir / f"{stem}_nuclei_class_masked.tif", nuclei_class_masked)

    if save_colored_previews or save_overview_png:
        tissue_rgb = colorize_mask(tissue_pred, TISSUE_COLORS)
        nuclei_fg_rgb = colorize_mask(nuclei_fg_pred, NUCLEI_FG_COLORS)
        nuclei_class_rgb = colorize_mask(nuclei_class_masked, NUCLEI_COLORS_WITH_BG)

        if save_colored_previews:
            Image.fromarray(tissue_rgb).save(output_dir / f"{stem}_tissue_colored.png")
            Image.fromarray(nuclei_fg_rgb).save(output_dir / f"{stem}_nuclei_fg_colored.png")
            Image.fromarray(nuclei_class_rgb).save(output_dir / f"{stem}_nuclei_class_colored.png")

            save_overlay(
                image_rgb=img,
                color_mask_rgb=tissue_rgb,
                save_path=output_dir / f"{stem}_tissue_overlay.png",
                alpha=0.45,
            )
            save_overlay(
                image_rgb=img,
                color_mask_rgb=nuclei_class_rgb,
                save_path=output_dir / f"{stem}_nuclei_class_overlay.png",
                alpha=0.45,
            )

        if save_overview_png:
            make_overview_png(
                image_rgb=img,
                tissue_rgb=tissue_rgb,
                nuclei_fg_rgb=nuclei_fg_rgb,
                nuclei_class_rgb=nuclei_class_rgb,
                save_path=output_dir / f"{stem}_overview.png",
            )

    print_class_counts("Tissue", tissue_pred, TISSUE_ID_TO_NAME)
    print_class_counts("Nuclei foreground", nuclei_fg_pred, {0: "background", 1: "nuclei"})
    print_class_counts("Nuclei class masked", nuclei_class_masked, NUCLEI_ID_TO_NAME, ignore_id=255)

    print("\nInference finished.")
    print(f"Saved outputs to: {output_dir}")
    print("\nTissue output uses official PUMA IDs:")
    for k, v in TISSUE_ID_TO_NAME.items():
        print(f"  {k}: {v}")

    print("\nColored files are only for visualization. Raw .tif/.npy masks keep the class IDs.")


if __name__ == "__main__":
    run_inference()
# Out:
# Using device: cuda
# /content/encoder/engine.py:52: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_amp):
# Loaded checkpoint: /content/drive/MyDrive/Research/PUMA/checkpoints_encoder/E6_UNIv2_lora/fold_1/best_model.pth
# Checkpoint epoch: 15
# /tmp/ipykernel_3182/2822000641.py:335: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_amp):
# Tissue pixel counts:
#   3: tumor: 980395
#   5: necrosis: 68181
#
# Nuclei foreground pixel counts:
#   0: background: 798439
#   1: nuclei: 250137
#
# Nuclei class masked pixel counts:
#   0: tumor: 219320
#   1: lymphocyte: 448
#   5: neutrophil: 118
#   9: apoptosis: 30251
#   255: background_or_non_nuclei: 798439
#
# Inference finished.
# Saved outputs to: /content/drive/MyDrive/Research/PUMA/e6_inference_outputs
#
# Tissue output uses official PUMA IDs:
#   0: background
#   1: stroma
#   2: blood_vessel
#   3: tumor
#   4: epidermis
#   5: necrosis
#
# Colored files are only for visualization. Raw .tif/.npy masks keep the class IDs.
